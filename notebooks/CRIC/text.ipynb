# %%
import sys
sys.path.append('..')

from modules.analysis.color import extract_image_colors

# %%
extract_image_colors(r'C:\Users\paolo\OneDrive\Desktop\Projects\Drcadx\data\cric_cropped\Base balanceada dividida\6 classes\Validacao\9_0_.png')
# Out:
# Done: 8099/8100
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
